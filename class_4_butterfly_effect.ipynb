# %% [markdown]
# # Butterfly Effect, aka sensitivity to initial conditions
# Show the big impact that a small variation at the beginning has further down the line.

# %% [markdown]
# ### Exercise 1:

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
nsteps = 100
x = np.zeros(nsteps)

starting_points = [0.6, 0.6001]
fig = plt.figure(figsize=(14,7))

for x[0] in starting_points:
    r = 3.7
    for i in range(1,nsteps):
        x[i] = r*x[i-1]*(1-x[i-1])
    plt.plot(x);
plt.ylim((0,1));

# %% [markdown]
# ### Exercise 2: Prediction horizon
# Role playing: let's imagine we actually use this equation to predict something. How far in the future can we reasonably expect to predict?
#
# * If the question is about time, the answer will probably include a plot that has time as the horizontal axis.
# * If we have a plot with time as axis and the question is about prediction quality, then probably the vertical axis will be some kind of prediction quality.
# * Option 1: use pairs of trajectories, calculate mean(abs(difference)) for each point in time. Option 2: use a family of trajectories; noisify (wiggle, shake?) the starting point, check how much variance it creates at each of the consecutive points.

# %%
# Check that normally distributed random numbers generated by numpy actually look normal
plt.plot(np.random.randn(1000),np.random.randn(1000),'.');

# %%
# Yes, looks like noise should look.

# %%
nsteps = 100
ntraces = 20
x = np.zeros(shape=(nsteps,ntraces))
wiggle = 0.0001                           # standard deviation of the original noise in X0
r = 3.7
for itrace in range(ntraces):
    x[0,itrace] = 0.6+np.random.randn(1)*wiggle
    for istep in range(1,nsteps):
        x[istep, itrace] = r*x[istep-1,itrace]*(1-x[istep-1,itrace])
fig = plt.figure(figsize=(14,7))
plt.plot(x);
plt.ylim((0.1));
plt.xlabel('Time');
plt.ylabel('All trajectories');

# %% [markdown]
# Each column in this setup is a 'trajectory,' or one of the lines plotted in Exercise 1.
#
# We want to get standard deviation for all trajectories at each point in time.

# %%
nsteps = 100
ntraces = 20
x = np.zeros(shape=(nsteps,ntraces))
wiggle = 0.0001                           # standard deviation of the original noise in X0
r = 2.7
for itrace in range(ntraces):
    x[0,itrace] = 0.6+np.random.randn(1)*wiggle
    for istep in range(1,nsteps):
        x[istep, itrace] = r*x[istep-1,itrace]*(1-x[istep-1,itrace])
fig = plt.figure(figsize=(14,7))
plt.plot(np.std(x,axis=1));
plt.xlabel('Time');
plt.ylabel('Variability (sd) of trajectories');

# %%
nsteps = 100
ntraces = 20
x = np.zeros(shape=(nsteps,ntraces))
wiggle = 0.0001                           # standard deviation of the original noise in X0
for itrace in range(ntraces):
    x[0,itrace] = 0.6+np.random.randn(1)*wiggle
    for istep in range(1,nsteps):
        x[istep, itrace] = r*x[istep-1,itrace]*(1-x[istep-1,itrace])
fig = plt.figure(figsize=(14,7))
plt.plot(np.std(x,axis=1));
plt.xlabel('Time');
plt.ylabel('Variability (sd) of trajectories');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-cb64a89f2624> in <module>
#       7     x[0,itrace] = 0.6+np.random.randn(1)*wiggle
#       8     for istep in range(1,nsteps):
# ----> 9         x[istep, itrace] = r*x[istep-1,itrace]*(1-x[istep-1,itrace])
#      10 fig = plt.figure(figsize=(14,7))
#      11 plt.plot(np.std(x,axis=1));
#
# TypeError: can't multiply sequence by non-int of type 'numpy.float64'

# %% [markdown]
# This shows the standard deviation of the trajectories.
