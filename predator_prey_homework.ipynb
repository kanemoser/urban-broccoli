# %% [markdown]
# # Predator-Prey homework

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Attempt to test only c:

# %%
nsteps = 20000
a = 0.6 # bunny reproduction
b = 1.2 # bunny predation
c = 0.5 # bunny-fox conversion rate
d = 1 # fox death

dt = 0.001 # step

possible_cs = [0.1, 0.3, 0.5, 0.7, 0.9, 1]

x = np.zeros(nsteps)
y = np.zeros(nsteps)

fig1 = plt.figure(figsize=(16,5));
fig2 = plt.figure(figsize=(5,5));
ax2 = plt.axes()
ax3 = plt.axes()

for itrial in range(len(possible_cs)):
    c = possible_cs[itrial]
    x[0] = 1
    y[0] = 1

    for t in range(1,nsteps):
        x[t] = x[t-1] + dt*(a*x[t-1] - b*x[t-1]*y[t-1])
        y[t] = y[t-1] + dt*(c*x[t-1]*y[t-1] - d*y[t-1])

    ax1 = fig1.add_subplot(1,len(possible_cs),itrial+1);
    ax1.plot(x, label='Bunnies');
    ax1.plot(y, label='Foxes');
    ax1.legend(loc='upper right');

    ax2.plot(x,y, label=c);
    plt.xlabel('Bunnies');
    plt.ylabel('Foxes');
 
ax2.legend(loc='upper right');
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# Attempt to test only b:

# %%
nsteps = 20000
a = 0.6 # bunny reproduction
b = 1.2 # bunny predation
c = 0.5 # bunny-fox conversion rate
d = 1 # fox death

dt = 0.001 # step

possible_bs = [0.5, 0.7, 0.9, 1.1, 1.3, 1.5]

x = np.zeros(nsteps)
y = np.zeros(nsteps)

fig1 = plt.figure(figsize=(16,5));
fig2 = plt.figure(figsize=(5,5));
ax2 = plt.axes()
ax3 = plt.axes()

for itrial in range(len(possible_bs)):
    b = possible_bs[itrial]
    x[0] = 1
    y[0] = 1

    for t in range(1,nsteps):
        x[t] = x[t-1] + dt*(a*x[t-1] - b*x[t-1]*y[t-1])
        y[t] = y[t-1] + dt*(c*x[t-1]*y[t-1] - d*y[t-1])

    ax1 = fig1.add_subplot(1,len(possible_bs),itrial+1);
    ax1.plot(x, label='Bunnies');
    ax1.plot(y, label='Foxes');
    ax1.legend(loc='upper right');

    ax2.plot(x,y, label=b);
    plt.xlabel('Bunnies');
    plt.ylabel('Foxes');
 
ax2.legend(loc='upper right');
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# Attempt to test both at once:

# %%
nsteps = 20000
a = 0.6 # bunny reproduction
b = 1.2 # bunny predation
c = 0.5 # bunny-fox conversion rate
d = 1 # fox death

dt = 0.001 # step

possible_cs = [0.1, 0.3, 0.5, 0.7, 0.9, 1]
possible_bs = [0.5, 0.7, 0.9, 1.1, 1.3, 1.5]

x = np.zeros(nsteps)
y = np.zeros(nsteps)

fig1 = plt.figure(figsize=(16,5));
fig2 = plt.figure(figsize=(5,5));
ax2 = plt.axes()
ax3 = plt.axes()

for itrial in range(len(possible_cs)):
    c = possible_cs[itrial]
    x[0] = 1
    y[0] = 1
    
for itrial in range(len(possible_bs)):
    b = possible_bs[itrial]
    x[0] = 1
    y[0] = 1

    for t in range(1,nsteps):
        x[t] = x[t-1] + dt*(a*x[t-1] - b*x[t-1]*y[t-1])
        y[t] = y[t-1] + dt*(c*x[t-1]*y[t-1] - d*y[t-1])

    ax1 = fig1.add_subplot(1,len(possible_cs),itrial+1)
    ax1.plot(x, label='Bunnies');
    ax1.plot(y, label='Foxes');
    ax1.legend(loc='upper right');

    ax2.plot(x,y, label=c);
    plt.xlabel('Bunnies');
    plt.ylabel('Foxes');
        
    ax3.plot(x,y, label=b);
    plt.xlabel('Bunnies');
    plt.ylabel('Foxes');
 
ax2.legend(loc='upper right');
ax3.legend(loc='upper right');
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# In the attempt above, I tried to simultaneously test different values for c, the fox to bunny conversion rate, and b, the bunny predation rate. I experimented with indenting to try to create a nested loop to accomplish this, but came up with errors each time. When I only test c or b, the program works, so I could just copy-paste and run it separately for each parameter, but I want to figure out how to do them all at the same time. I googled the error message that I keep getting, which relates to the axis labels, but I still cannot figure out how to fix it.
#
# When I test only c, as its value increases so does the foxes' ability to reproduce, and their population begins to head toward overtaking the bunnies. When I test only b, as its value increases the fox population shrinks. This makes sense because higher predation on bunnies would quickly deplete their population and leave the foxes starving; however, I do not understand why the bunny population remains the same on this graph.
